# %%
import pandas as pd

# %%
#open and read the dataset file
url = ('/IIT/FYP/Python/data_final.csv')
data = pd.read_csv(url, header = 0)
data = data.drop(index=0)

# %%
#get dataset values count
data['Disease'].value_counts()
# Out:
# CLL                  337
# Normal               319
# HCL                  311
# CML                  311
# Leukemia Positive    303
# Name: Disease, dtype: int64

# %%
df = pd.DataFrame(data)
df.describe()
# Out:
#                WBC          HGB         NENO        LYMNO         MONO  \
# count  1581.000000  1581.000000  1581.000000  1581.000000  1581.000000
# mean      7.404554    13.780076     4.043580     2.479886     0.820810
# std       2.269145     1.430907     1.678691     1.016734     0.420221
# min       2.300000     8.900000     0.800000     0.400000     0.200000
# 25%       5.800000    12.800000     2.800000     1.800000     0.500000
# 50%       7.100000    13.700000     3.800000     2.300000     0.700000
# 75%       8.600000    14.800000     4.900000     3.000000     1.100000
# max      18.200000    18.800000    15.800000     8.100000     1.800000
#
#              EONO         BANO          HCT          MCV          PLT
# count  1581.00000  1581.000000  1581.000000  1581.000000  1581.000000
# mean      0.21265     0.087034    40.748703    87.537698   251.753321
# std       0.20612     0.053982     4.044389     5.814967    68.206461
# min       0.00000     0.000000    28.600000    62.100000    18.000000
# 25%       0.10000     0.100000    37.900000    84.200000   205.000000
# 50%       0.20000     0.100000    40.600000    87.700000   244.000000
# 75%       0.30000     0.100000    43.400000    91.300000   290.000000
# max       3.60000     0.300000    55.400000   105.800000   698.000000

# %%
# names = ['WBC', 'HGB', 'NENO', 'LYMNO', 'MONO', 'EONO', 'BANO', 'HCT', 'MCV', 'PLT', 'Disease']
df.hist(column='PLT', bins = 10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11df49b20>]],
#       dtype=object)
